# %% [markdown]
# Time & Space Complexity of List, Set, and Dictionary Operations (Python / DSA)
# ________________________________________
# 🎓 Introduction: Why This Section Is Critical
# Everyone, please pay close attention to this Section.
# This is one of the most important Sections in Data Structures and Algorithms.
# In your future:
# •	You will solve 200, 300, 400+ DSA questions
# •	You will repeatedly use lists, sets, and dictionaries
# •	You will perform operations like:
# o	add
# o	delete
# o	insert
# o	search
# o	iterate
# o	slice
# Now here is the key point most students ignore:
# Writing correct code is not enough.
# You must know the time complexity of every operation you use.
# In interviews, you may write only 4–5 lines of code,
# but if you don’t know the time complexity of:
# •	append
# •	pop
# •	insert
# •	in
# •	copy
# you will fail to explain the overall complexity of your solution.
# That is why this Section matters.
# ________________________________________
# 🧾 Part 1: List Operations and Their Time Complexity
# Let us go step by step through the most important list operations.
# ________________________________________
# 1️⃣ Copying a List
# Operation:
# list2 = list1.copy()
# How Python Works Internally:
# •	Python copies elements one by one
# •	Every element is read and placed into a new list
# If the list has n elements,
# Python performs n copy operations.
# Time Complexity:
# 👉 O(n)
# 📌 Key idea:
# Copying depends on the size of the list.
# ________________________________________
# 2️⃣ Append (Add at the End)
# Operation:
# list.append(7)
# Important Observation:
# •	The element is added only at the end
# •	No shifting of elements is required
# •	List size does not matter
# Whether the list has:
# •	2 elements
# •	10 elements
# •	1 crore elements
# append still takes the same time.
# Time Complexity:
# 👉 O(1) (Constant time)
# 📌 Key idea:
# Appending is fast and size-independent.
# ________________________________________
# 3️⃣ Pop from the End
# Operation:
# list.pop()
# •	Removes the last element
# •	No shifting required
# Time Complexity:
# 👉 O(1)
# 📌 Key idea:
# Removing the last element is always constant time.
# ________________________________________
# 4️⃣ Pop from an Index (Middle or Beginning)
# Operation:
# list.pop(0)   # or any middle index
# What Actually Happens:
# •	After removing the element,
# •	All elements shift one position left
# If the list has n elements,
# almost n − 1 elements may need shifting.
# Worst Case:
# Removing the first element.
# Time Complexity:
# 👉 O(n)
# 📌 Key idea:
# Any removal that causes shifting is linear time.
# ________________________________________
# 5️⃣ Insert at a Position
# Operation:
# list.insert(index, value)
# What Python Does:
# •	Shifts elements to make space
# •	Inserts the new value
# Worst Case:
# Insert at the beginning.
# Time Complexity:
# 👉 O(n)
# 📌 Key idea:
# Insert ≈ shift ≈ linear time.
# ________________________________________
# 6️⃣ Get an Element (Index Access)
# Operation:
# list[4]
# •	Python directly jumps to the memory location
# •	No iteration required
# List size does not matter.
# Time Complexity:
# 👉 O(1)
# 📌 Key idea:
# Index access in a list is constant time.
# ________________________________________
# 7️⃣ Set (Update) an Element
# Operation:
# list[4] = 100
# •	Direct memory update
# •	No dependency on list size
# Time Complexity:
# 👉 O(1)
# ________________________________________
# 8️⃣ Delete an Element
# Operation:
# del list[index]
# •	Internally similar to pop(index)
# •	Causes shifting
# Time Complexity:
# 👉 O(n)
# ________________________________________
# 9️⃣ Iteration (Looping Through List)
# Operation:
# for x in list:
#     print(x)
# •	Visits every element once
# Time Complexity:
# 👉 O(n)
# ________________________________________
# 🔟 Slicing a List
# Operation:
# list[2:5]
# Let the slice length be k.
# Python:
# •	Copies those k elements
# •	Creates a new list
# Time Complexity:
# 👉 O(k)
# 📌 Important:
# Slice length matters, not original list length.
# ________________________________________
# 1️⃣1️⃣ Delete a Slice
# Operation:
# del list[2:5]
# Two things happen:
# 1.	Elements are removed → O(k)
# 2.	Remaining elements shift → O(n) (worst case)
# Overall (Worst Case):
# 👉 O(n)
# ________________________________________
# 1️⃣2️⃣ Sorting a List
# Operation:
# list.sort()
# Python uses Timsort.
# Time Complexity:
# 👉 O(n log n)
# 📌 For now, just remember n log n.
# Sorting algorithms will be covered separately.
# ________________________________________
# 1️⃣3️⃣ Membership Check in List
# Operation:
# x in list
# Python:
# •	Checks elements one by one
# •	Stops if found
# Worst Case:
# Element is last or not present.
# Time Complexity:
# 👉 O(n)
# ________________________________________
# 1️⃣4️⃣ Min / Max in List
# Operation:
# min(list)
# max(list)
# Python must:
# •	Traverse entire list
# •	Compare all elements
# Time Complexity:
# 👉 O(n)
# ________________________________________
# 1️⃣5️⃣ Length of List
# Operation:
# len(list)
# Important clarification:
# Python does NOT count elements one by one.
# It stores the length internally.
# Time Complexity:
# 👉 O(1)
# 📌 This is a common interview trap.
# ________________________________________
# 🧮 Part 2: Set Operations
# Now let’s move to sets.
# Membership Check in Set
# Operation:
# x in my_set
# Average Case:
# 👉 O(1)
# Why?
# •	Sets use hashing
# •	Direct access, not iteration
# Worst Case (Rare):
# 👉 O(n) (due to hash collisions)
# 📌 In interviews, say:
# “Average case O(1), worst case O(n), but worst case is rare.”
# ________________________________________
# 📚 Part 3: Dictionary Operations
# Dictionaries are key–value pairs.
# ________________________________________
# Membership Check (Key Exists?)
# Operation:
# key in dict
# Average Case:
# 👉 O(1)
# Worst Case:
# 👉 O(n) (rare, due to collisions)
# ________________________________________
# Get a Value
# Operation:
# dict[key]
# Average Case:
# 👉 O(1)
# ________________________________________
# Set / Update a Value
# Operation:
# dict[key] = value
# Average Case:
# 👉 O(1)
# ________________________________________
# Delete a Key
# Operation:
# del dict[key]
# Average Case:
# 👉 O(1)
# ________________________________________
# Copy a Dictionary
# Operation:
# dict.copy()
# •	Copies all key–value pairs
# Time Complexity:
# 👉 O(n)
# ________________________________________
# Iterate Over Dictionary
# Operation:
# for k, v in dict.items():
# •	Visits every entry
# Time Complexity:
# 👉 O(n)
# ________________________________________
# 🧠 Final Professor Advice (Very Important)
# Let me conclude this Section with something crucial:
# •	These time complexities must become instinct
# •	You should not calculate them consciously every time
# •	After solving enough questions, they should come automatically
# In future DSA problems, I will say things like:
# •	“This is O(1)”
# •	“This becomes O(n)”
# •	“Overall complexity is O(n log n)”
# And you should immediately understand why.
# If you understand this Section well,
# half of DSA interviews become easier.
# We will use these operations repeatedly.
# See you in the next Section.
# ________________________________________
