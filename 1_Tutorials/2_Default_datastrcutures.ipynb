# %% [markdown]
# ---
#
# # 🧠 PYTHON DEFAULT DATA STRUCTURES – MASTER CHEATSHEET
#
# We’ll cover:
#
# 1. ✅ Core Properties (Ordered, Mutable, etc.)
# 2. ✅ Common Operations Side-by-Side
# 3. ✅ Sorting / min / max / lambda / map / filter
# 4. ✅ Special / Unique Methods (where confusion usually happens)
# 5. ✅ High-Confusion Traps Section (VERY important)
#
# ---
#
# # 1️⃣ CORE PROPERTIES
#
# | Feature    | String  | List    | Tuple   | Set     | Dictionary             |
# | ---------- | ------- | ------- | ------- | ------- | ---------------------- |
# | Ordered    | ✅ Yes   | ✅ Yes   | ✅ Yes   | ❌ No    | ✅ Yes (Py 3.7+)        |
# | Mutable    | ❌ No    | ✅ Yes   | ❌ No    | ✅ Yes   | ✅ Yes                  |
# | Duplicates | ✅ Yes   | ✅ Yes   | ✅ Yes   | ❌ No    | ❌ Keys No (Values Yes) |
# | Indexed    | ✅ Yes   | ✅ Yes   | ✅ Yes   | ❌ No    | ❌ No (Key-based)       |
# | Syntax     | `"abc"` | `[1,2]` | `(1,2)` | `{1,2}` | `{"a":1}`              |
#
# ⚠ Important:
#
# * Dictionary is ordered (since Python 3.7), but **not indexable**
# * Set is unordered → no indexing, no slicing
#
# ---
#
# # 2️⃣ INSERT / UPDATE / DELETE (Side by Side)
#
# ### 🔹 Insert One Item
#
# | Operation     | String        | List        | Tuple | Set      | Dictionary          |
# | ------------- | ------------- | ----------- | ----- | -------- | ------------------- |
# | Insert 1 item | ❌ (immutable) | `append(x)` | ❌     | `add(x)` | `dict[key] = value` |
#
# ⚠ CONFUSION:
#
# * List → `append()`
# * Set → `add()`
# * Dict → assignment
# * Tuple → cannot
# * String → cannot
#
# ---
#
# ### 🔹 Insert Multiple Items (Bulk Insert)
#
# | Structure | Method              |
# | --------- | ------------------- |
# | List      | `extend(iterable)`  |
# | Set       | `update(iterable)`  |
# | Tuple     | ❌ (new tuple only)  |
# | String    | ❌ (new string only) |
# | Dict      | `update(dict2)`     |
#
# ⚠ Pattern:
#
# * List → extend
# * Set → update
# * Dict → update
#
# ---
#
# ### 🔹 Update Existing Value
#
# | Structure | How                 |
# | --------- | ------------------- |
# | List      | `lst[i] = value`    |
# | Dict      | `dict[key] = value` |
# | Set       | ❌ (no indexing)     |
# | Tuple     | ❌                   |
# | String    | ❌                   |
#
# ---
#
# ### 🔹 Delete
#
# | Structure | Delete by value            | Delete by index | Clear     |
# | --------- | -------------------------- | --------------- | --------- |
# | List      | `remove(x)`                | `pop(i)`        | `clear()` |
# | Set       | `remove(x)` / `discard(x)` | ❌               | `clear()` |
# | Dict      | `pop(key)`                 | ❌               | `clear()` |
# | Tuple     | ❌                          | ❌               | ❌         |
# | String    | ❌                          | ❌               | ❌         |
#
# ⚠ Difference:
#
# * `remove()` → error if not found
# * `discard()` (set only) → no error
#
# ---
#
# # 3️⃣ SLICING
#
# | Structure | Supports Slicing? |
# | --------- | ----------------- |
# | String    | ✅                 |
# | List      | ✅                 |
# | Tuple     | ✅                 |
# | Set       | ❌                 |
# | Dict      | ❌                 |
#
# Example:
#
# ```python
# lst[1:4]
# ```
#
# Set & dict do not support slicing.
#
# ---
#
# # 4️⃣ SORTING
#
# | Structure | Sorting Method              |
# | --------- | --------------------------- |
# | List      | `lst.sort()` (in-place)     |
# | List      | `sorted(lst)`               |
# | Tuple     | `sorted(tuple)`             |
# | String    | `sorted(string)`            |
# | Set       | `sorted(set)`               |
# | Dict      | `sorted(dict)` → sorts keys |
#
# ⚠ Important:
#
# * Only LIST has `.sort()`
# * Everything else → `sorted()`
#
# ---
#
# # 5️⃣ MIN / MAX
#
# Works on:
#
# * List
# * Tuple
# * Set
# * String
# * Dict (keys only)
#
# #### Dictionary Special Case
#
# ```python
# min(dic, key=dic.get)
# ```
#
# ⚠ DO NOT write:
#
# ```python
# min(dic, key=dic.get())  ❌
# ```
#
# Because:
#
# * `key` expects function
# * `dic.get` → function reference
# * `dic.get()` → function call
#
# ---
#
# # 6️⃣ LAMBDA / MAP / FILTER
#
# Works with:
#
# * List
# * Tuple
# * Set
# * Dict (on keys or items)
#
# Example:
#
# ```python
# list(map(lambda x: x*2, lst))
# ```
#
# Dictionary example:
#
# ```python
# dict(map(lambda item: (item[0], item[1]*2), dic.items()))
# ```
#
# ---
#
# # 7️⃣ SPECIAL METHODS (HIGH CONFUSION ZONE)
#
# ---
#
# ### 🔵 STRING SPECIAL METHODS
#
# Only strings have:
#
# * `split()`
# * `join()`
# * `replace()`
# * `strip()`
# * `startswith()`
# * `endswith()`
# * `lower()`
# * `upper()`
# * `find()`
# * `count()`
#
# ⚠ Strings are immutable → all return new string
#
# ---
#
# ### 🟢 LIST SPECIAL METHODS
#
# Only lists have:
#
# * `append()`
# * `extend()`
# * `insert()`
# * `sort()`
# * `reverse()`
# * `pop(index)`
# * `remove(value)`
#
# ---
#
# ### 🟡 TUPLE SPECIAL
#
# Very limited:
#
# * `count()`
# * `index()`
#
# Tuple is immutable.
#
# ---
#
# ### 🔴 SET SPECIAL METHODS
#
# Unique to set:
#
# * `add()`
# * `update()`
# * `remove()`
# * `discard()`
# * `intersection()`
# * `union()`
# * `difference()`
# * `symmetric_difference()`
#
# ⚠ Only set supports mathematical operations like:
#
# ```python
# a & b
# a | b
# a - b
# a ^ b
# ```
#
# ---
#
# ### 🟣 DICTIONARY SPECIAL METHODS
#
# Only dict has:
#
# * `keys()`
# * `values()`
# * `items()`
# * `get()`
# * `popitem()`
# * `setdefault()`
# * `update()`
#
# ---
#
# # 8️⃣ VERY IMPORTANT CONFUSION TRAPS
#
# #### ❌ No append in set
#
# Use:
#
# ```python
# set.add()
# ```
#
# ---
#
# #### ❌ No extend in set
#
# Use:
#
# ```python
# set.update()
# ```
#
# ---
#
# #### ❌ No indexing in set
#
# Cannot do:
#
# ```python
# set[0]
# ```
#
# ---
#
# #### ❌ No slicing in dict
#
# Cannot do:
#
# ```python
# dict[0:2]
# ```
#
# ---
#
# #### ❌ Cannot modify string
#
# ```python
# s[0] = "A" ❌
# ```
#
# ---
#
# #### ❌ Dictionary keys must be immutable
#
# Allowed:
#
# * int
# * string
# * tuple
#
# Not allowed:
#
# * list
# * set
#
# ---
#
# # 9️⃣ MENTAL MODEL (To Stop Confusion Forever)
#
# Think like this:
#
# * STRING → text processing
# * LIST → ordered collection with duplicates
# * TUPLE → fixed data record
# * SET → unique math collection
# * DICT → key-value mapping
#
# ---
#
# # 🔟 QUICK DECISION FLOW
#
# If you need:
#
# * Ordered + mutable + duplicates → LIST
# * Unique items → SET
# * Key-value mapping → DICT
# * Immutable record → TUPLE
# * Text manipulation → STRING
#
# ---
#
# # 🚀 FINAL MEMORY TRICK
#
# | Structure | Add 1       | Add Many |
# | --------- | ----------- | -------- |
# | List      | append      | extend   |
# | Set       | add         | update   |
# | Dict      | dict[key]=v | update   |
# | Tuple     | ❌           | ❌        |
# | String    | ❌           | ❌        |
#
# Memorize this row — 80% confusion solved.
#
# ---
#
# If you want, I can also create:
#
# * 🔥 Printable PDF format
# * 🔥 Visual mind map version
# * 🔥 Interview rapid-fire version
# * 🔥 Practice MCQ confusion test
# * 🔥 Real coding examples per structure
#
# Tell me how you prefer to revise.

# %% [markdown]
# ---
#
# # 🔹 1️⃣ Declaring Empty Data Structures
#
# | Type   | Literal Syntax | Constructor | Notes             |
# | ------ | -------------- | ----------- | ----------------- |
# | String | `""` or `''`          | `str()`     | Immutable         |
# | List   | `[]`           | `list()`    | Mutable           |
# | Tuple  | `()`           | `tuple()`   | Immutable         |
# | Set    | `{}` | `set()`     | ❌ `{}` creates dict |
# | Dict   | `{}`           | `dict()`    | Key-Value         |
#
# ⚠ Important:
#
# ```python
# {}        # dictionary
# set()     # empty set
# ```
#
# ---
#
# # 🔹 2️⃣ Inter-Conversion Cheat Sheet
#
# ### 🧠 Universal Rule
#
# Almost everything can be converted using:
#
# ```python
# list()
# tuple()
# set()
# dict()
# str()
# ```
#
# But behavior depends on structure.
#
# ---
#
# # 🔁 STRING CONVERSIONS
#
# ### String → List
#
# ```python
# list("abc")
# # ['a', 'b', 'c']
# ```
#
# Split version:
#
# ```python
# "hello world".split()
# # ['hello', 'world']
# ```
#
# Custom separator:
#
# ```python
# "a,b,c".split(",")
# ```
#
# ---
#
# ### String → Tuple
#
# ```python
# tuple("abc")
# # ('a','b','c')
# ```
#
# ---
#
# ### String → Set
#
# ```python
# set("banana")
# # {'b','a','n'}  # unique only
# ```
#
# ---
#
# ### String → Dict (Special Case)
#
# Must convert key-value pairs:
#
# ```python
# dict([("a",1),("b",2)])
# ```
#
# Or:
#
# ```python
# dict(a=1, b=2)
# ```
#
# ---
#
# # 🔁 LIST CONVERSIONS
#
# ### List → String
#
# Only if elements are strings:
#
# ```python
# "".join(['a','b','c'])
# # 'abc'
# ```
#
# With separator:
#
# ```python
# ",".join(['a','b'])
# ```
#
# ⚠ join works ONLY on strings.
#
# ---
#
# ### List → Tuple
#
# ```python
# tuple([1,2,3])
# ```
#
# ---
#
# ### List → Set
#
# ```python
# set([1,2,2,3])
# # {1,2,3}
# ```
#
# Removes duplicates automatically.
#
# ---
#
# ### List → Dict
#
# Must be pairs:
#
# ```python
# dict([("a",1),("b",2)])
# ```
#
# OR indexed:
#
# ```python
# dict(enumerate(["a","b","c"]))
# # {0:'a',1:'b',2:'c'}
# ```
#
# ---
#
# # 🔁 TUPLE CONVERSIONS
#
# Exactly like list:
#
# ```python
# list((1,2))
# set((1,2))
# dict(((1,"a"),(2,"b")))
# ```
#
# ---
#
# # 🔁 SET CONVERSIONS
#
# ### Set → List
#
# ```python
# list({1,2,3})
# ```
#
# ### Set → Tuple
#
# ```python
# tuple({1,2})
# ```
#
# ⚠ Order NOT guaranteed.
#
# ---
#
# # 🔁 DICTIONARY CONVERSIONS
#
# ### Dict → List
#
# ```python
# list(d)          # keys only
# list(d.keys())
# list(d.values())
# list(d.items())
# ```
#
# Example:
#
# ```python
# d = {'a':1,'b':2}
# list(d.items())
# # [('a',1), ('b',2)]
# ```
#
# ---
#
# ### Dict → Tuple
#
# ```python
# tuple(d.items())
# ```
#
# ---
#
# ### Dict → Set
#
# ```python
# set(d)            # keys
# set(d.items())    # key-value pairs
# ```
#
# ---
#
# # 🔹 3️⃣ Special Conversion Methods
#
# | Operation     | Method         |
# | ------------- | -------------- |
# | List → String | `"sep".join()` |
# | String → List | `.split()`     |
# | Dict keys     | `.keys()`      |
# | Dict values   | `.values()`    |
# | Dict pairs    | `.items()`     |
# | Index mapping | `enumerate()`  |
# | Zip two lists | `zip()`        |
#
# ---
#
# # 🔹 4️⃣ String ↔ List Deep Dive
#
# #### Split Variations
#
# ```python
# text.split()            # whitespace
# text.split(",")         # custom
# text.split(",", 1)      # max split
# ```
#
# #### Join Variations
#
# ```python
# "-".join(list)
# ```
#
# #### Reverse string
#
# ```python
# s[::-1]
# ```
#
# ---
#
# # 🔹 5️⃣ Dictionary Conversion Patterns
#
# ### Two Lists → Dict
#
# ```python
# keys = ['a','b']
# values = [1,2]
#
# dict(zip(keys, values))
# ```
#
# ---
#
# ### Dict → Swapped Dict
#
# ```python
# {k:v for v,k in d.items()}
# ```
#
# ---
#
# ### Dict → String
#
# ```python
# str(d)
# ```
#
# OR formatted:
#
# ```python
# ", ".join(f"{k}:{v}" for k,v in d.items())
# ```
#
# ---
#
# # 🔹 6️⃣ Set Conversion Patterns
#
# Remove duplicates:
#
# ```python
# unique = list(set(my_list))
# ```
#
# Set to frozen set (immutable):
#
# ```python
# frozenset(my_set)
# ```
#
# ---
#
# # 🔹 7️⃣ Complete Slicing Guide
#
# Slicing works on:
#
# * String
# * List
# * Tuple
#
# ❌ Not on:
#
# * Set
# * Dict
#
# ---
#
# ### Basic Syntax
#
# ```python
# sequence[start:stop:step]
# ```
#
# Defaults:
#
# ```
# start = 0
# stop = len(sequence)
# step = 1
# ```
#
# ---
#
# ### Examples
#
# #### First 3
#
# ```python
# a[:3]
# ```
#
# #### Skip first 2
#
# ```python
# a[2:]
# ```
#
# #### Copy
#
# ```python
# a[:]
# ```
#
# #### Reverse
#
# ```python
# a[::-1]
# ```
#
# #### Every 2nd element
#
# ```python
# a[::2]
# ```
#
# #### Reverse every 2nd
#
# ```python
# a[::-2]
# ```
#
# ---
#
# ### Negative Indexing
#
# ```python
# a[-1]    # last
# a[-2]    # second last
# ```
#
# ---
#
# ### Slice Assignment (Lists Only)
#
# ```python
# a[1:3] = [9,9]
# ```
#
# Delete via slicing:
#
# ```python
# del a[1:3]
# ```
#
# ---
#
# # 🔹 8️⃣ Very Important Confusion Fixes
#
# #### ❌ Cannot append in set
#
# ✔ Use:
#
# ```python
# my_set.add(value)
# ```
#
# #### ❌ Cannot index set
#
# ✔ Convert to list first
#
# ---
#
# #### ❌ Cannot modify tuple
#
# ✔ Convert to list → modify → convert back
#
# ---
#
# #### ❌ min(dict) returns key
#
# ✔ To get min by value:
#
# ```python
# min(d, key=d.get)
# ```
#
# NOT:
#
# ```python
# d.get()
# ```
#
# Because `key=` expects function reference.
#
# ---
#
# #### Removing duplicates but keep order
#
# ```python
# list(dict.fromkeys(my_list))
# ```
#
# ---
#
# #### Safe dict access
#
# ```python
# d.get("key", default)
# ```
#
# ---
#
# # 🔹 Mental Model (Very Important)
#
# | Structure | Memory Type        | Use When        |
# | --------- | ------------------ | --------------- |
# | String    | Immutable sequence | Text            |
# | List      | Mutable ordered    | General purpose |
# | Tuple     | Immutable ordered  | Fixed data      |
# | Set       | Mutable unordered  | Unique elements |
# | Dict      | Key-Value mapping  | Fast lookup     |
#
# ---
#
# # 🔹 Pro Tip (Advanced)
#
# Check type before converting:
#
# ```python
# isinstance(x, list)
# ```
#
# Convert generically:
#
# ```python
# type(x)(iterable)
# ```
#
# ---
#
# # 🔥 Final Memory Trick
#
# If confused, ask:
#
# 1. Does it store key-value? → dict
# 2. Need uniqueness? → set
# 3. Need order + change? → list
# 4. Need order + no change? → tuple
# 5. Text? → string
#
# -
