# %% [markdown]
# # 🧠 Python Packaging & Environment Cheatsheet
#
# ## Priority: **uv → pip → venv → toml**
#
# ---
#
# # 🚀 1️⃣ `uv` — Modern Python Package & Project Manager (PRIORITY)
#
# uv
#
# > ⚡ Extremely fast replacement for `pip`, `pip-tools`, `virtualenv`, `poetry` (partially)
#
# Built in Rust. Designed to be:
#
# * Very fast
# * Simple
# * Lockfile-based
# * Compatible with `pip`
# * Works with `pyproject.toml`
#
# ---
#
# ## 🔹 Install uv
#
# ```bash
# pip install uv
# ```
#
# Or via installer:
#
# ```bash
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
#
# ---
#
# # 🔥 Core Concepts of uv
#
# | Concept               | What It Does          |
# | --------------------- | --------------------- |
# | Project management    | Uses `pyproject.toml` |
# | Dependency resolution | Very fast             |
# | Lock file             | Creates `uv.lock`     |
# | Virtual environments  | Built-in              |
# | pip replacement       | Fully compatible      |
#
# ---
#
# # 📦 1. Create New Project
#
# ```bash
# uv init myproject
# cd myproject
# ```
#
# Creates:
#
# ```
# pyproject.toml
# ```
#
# ---
#
# # 📦 2. Add Dependencies
#
# ```bash
# uv add requests
# ```
#
# This:
#
# * Updates `pyproject.toml`
# * Creates/updates `uv.lock`
# * Installs dependency
#
# ---
#
# # 📦 3. Remove Dependency
#
# ```bash
# uv remove requests
# ```
#
# ---
#
# # 📦 4. Sync Environment
#
# ```bash
# uv sync
# ```
#
# Installs exactly what is in `uv.lock`.
#
# ---
#
# # 📦 5. Run Python Script
#
# ```bash
# uv run main.py
# ```
#
# Uses project virtual environment automatically.
#
# ---
#
# # 📦 6. Create Virtual Environment
#
# ```bash
# uv venv
# ```
#
# Or specify Python:
#
# ```bash
# uv venv --python 3.11
# ```
#
# ---
#
# # 📦 7. Install Like pip
#
# ```bash
# uv pip install flask
# uv pip list
# uv pip freeze
# ```
#
# Yes — it supports pip interface.
#
# ---
#
# # 🧠 uv vs pip
#
# | Feature               | uv       | pip             |
# | --------------------- | -------- | --------------- |
# | Speed                 | ⚡⚡⚡      | ⚡               |
# | Lockfile              | Yes      | No              |
# | Dependency resolution | Modern   | Basic           |
# | Virtual env           | Built-in | Separate (venv) |
# | Project management    | Yes      | No              |
#
# ---
#
# # 🧩 Typical Workflow with uv
#
# ```bash
# uv init
# uv add fastapi
# uv add uvicorn
# uv run main.py
# ```
#
# No need:
#
# * `python -m venv`
# * `pip install`
# * `requirements.txt`
#
# ---
#
# # 🎯 When to Use uv
#
# ✔ New projects
# ✔ Professional projects
# ✔ Faster dependency management
# ✔ Reproducible builds
#
# ---
#
# # ❌ When NOT to Use uv
#
# * Very old legacy projects
# * If team strictly uses pip-only workflow
#
# ---
#
# ---
#
# # 🐍 2️⃣ pip — Python Package Installer
#
# pip
#
# > Default package installer for Python.
#
# ---
#
# ## 🔹 Install Package
#
# ```bash
# pip install requests
# ```
#
# ---
#
# ## 🔹 Upgrade
#
# ```bash
# pip install --upgrade requests
# ```
#
# ---
#
# ## 🔹 Uninstall
#
# ```bash
# pip uninstall requests
# ```
#
# ---
#
# ## 🔹 Freeze Dependencies
#
# ```bash
# pip freeze > requirements.txt
# ```
#
# Install from file:
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ---
#
# ## 🔹 Show Info
#
# ```bash
# pip show requests
# pip list
# ```
#
# ---
#
# # 🧠 Limitations of pip
#
# * No lockfile
# * No dependency conflict resolution system
# * No project management
# * Slower than uv
#
# ---
#
# # 🌱 3️⃣ venv — Virtual Environment Tool
#
# venv
#
# > Built-in Python tool for isolated environments.
#
# ---
#
# ## 🔹 Create Virtual Environment
#
# ```bash
# python -m venv myenv
# ```
#
# ---
#
# ## 🔹 Activate
#
# Mac/Linux:
#
# ```bash
# source myenv/bin/activate
# ```
#
# Windows:
#
# ```bash
# myenv\Scripts\activate
# ```
#
# ---
#
# ## 🔹 Deactivate
#
# ```bash
# deactivate
# ```
#
# ---
#
# # 🧠 Why Virtual Environments?
#
# Without venv:
#
# ```
# All projects share same packages ❌
# ```
#
# With venv:
#
# ```
# Each project isolated ✔
# ```
#
# ---
#
# # 🔄 pip + venv Traditional Workflow
#
# ```bash
# python -m venv venv
# source venv/bin/activate
# pip install requests
# pip freeze > requirements.txt
# ```
#
# ---
#
# # 📄 4️⃣ toml — Configuration File Format
#
# TOML
#
# > Used in modern Python packaging via `pyproject.toml`
#
# ---
#
# ## 🔹 What is TOML?
#
# * Human-readable config format
# * Used by uv, poetry, modern tools
#
# ---
#
# ## 🔹 Example `pyproject.toml`
#
# ```toml
# [project]
# name = "myproject"
# version = "0.1.0"
# dependencies = [
#     "requests",
#     "fastapi"
# ]
# ```
#
# ---
#
# ## 🔹 Sections in TOML
#
# | Syntax        | Meaning      |
# | ------------- | ------------ |
# | `[section]`   | Table        |
# | `key = value` | Assignment   |
# | `[]`          | List         |
# | `{}`          | Inline table |
#
# ---
#
# # 🧠 Modern Python Packaging Flow
#
# ### Old Way
#
# ```
# venv → pip → requirements.txt
# ```
#
# ### Modern Way
#
# ```
# uv → pyproject.toml → uv.lock
# ```
#
# ---
#
# # 🚀 Recommended Learning Path
#
# 1️⃣ Learn uv deeply
# 2️⃣ Understand pip for legacy
# 3️⃣ Understand venv basics
# 4️⃣ Understand pyproject.toml
#
# ---
#
# # 🏆 Final Recommendation
#
# If starting fresh:
#
# > Use **uv** for everything.
#
# It replaces:
#
# * pip
# * pip-tools
# * virtualenv
# * partially poetry
#
# ---
#
# If you'd like, I can next create:
#
# * 🔥 uv vs poetry comparison
# * 🧪 Real-world project setup example
# * 🧠 Deep dive into pyproject.toml structure
# * 📦 How dependency resolution works internally
# * 🐳 Using uv with Docker
#
# Tell me your goal:
# 👉 Job-ready / production-ready / interview-focused / advanced packaging mastery

# %% [markdown]
# # 📚 Full Production Template Structure
#
# ## (dev → qa → stg → prod) using **uv + Docker**
#
# Using:
#
# * uv
# * Docker
# * `pyproject.toml` (PEP 621 standard)
#
# This is a **real-world enterprise-ready structure** you can use in startups or large systems.
#
# ---
#
# # 🏗 1️⃣ Recommended Production Folder Structure
#
# ```
# myapp/
# │
# ├── pyproject.toml
# ├── uv.lock
# ├── Dockerfile
# ├── docker-compose.yml
# ├── .env.dev
# ├── .env.qa
# ├── .env.stg
# ├── .env.prod
# │
# ├── src/
# │   ├── main.py
# │   ├── config.py
# │   ├── api/
# │   ├── services/
# │   ├── models/
# │   └── utils/
# │
# ├── tests/
# │
# ├── scripts/
# │   ├── migrate.sh
# │   └── seed.sh
# │
# └── .github/workflows/
#     └── ci.yml
# ```
#
# ---
#
# # 🌍 2️⃣ Environment Strategy (dev → qa → stg → prod)
#
# ## 🔹 Environment Meaning
#
# | Env      | Purpose                 |
# | -------- | ----------------------- |
# | **dev**  | Local developer machine |
# | **qa**   | Testing environment     |
# | **stg**  | Production-like staging |
# | **prod** | Live production         |
#
# ---
#
# # 🔐 3️⃣ Environment Variable Pattern
#
# Example `.env.dev`
#
# ```
# ENV=dev
# DEBUG=true
# DATABASE_URL=postgres://localhost/devdb
# ```
#
# `.env.prod`
#
# ```
# ENV=prod
# DEBUG=false
# DATABASE_URL=postgres://prod-server/db
# ```
#
# ---
#
# # 🧠 4️⃣ config.py (Clean Pattern)
#
# ```python
# import os
#
# class Settings:
#     ENV = os.getenv("ENV", "dev")
#     DEBUG = os.getenv("DEBUG", "false").lower() == "true"
#     DATABASE_URL = os.getenv("DATABASE_URL")
#
# settings = Settings()
# ```
#
# ---
#
# # 📦 5️⃣ pyproject.toml (Production-Ready)
#
# ```toml
# [project]
# name = "myapp"
# version = "1.0.0"
# requires-python = ">=3.11"
#
# dependencies = [
#     "fastapi",
#     "uvicorn",
#     "pydantic",
# ]
#
# [project.optional-dependencies]
# dev = [
#     "pytest",
#     "black",
#     "ruff"
# ]
#
# [tool.black]
# line-length = 88
# ```
#
# ---
#
# # 🚀 6️⃣ Development Workflow
#
# ### Install everything including dev:
#
# ```bash
# uv sync --extra dev
# ```
#
# ### Run locally:
#
# ```bash
# uv run uvicorn src.main:app --reload
# ```
#
# ---
#
# # 🧪 7️⃣ QA / CI Workflow
#
# In CI (GitHub Actions):
#
# ```bash
# uv sync --frozen --extra dev
# pytest
# ```
#
# Why `--frozen`?
#
# ✔ Ensures lockfile not modified
# ✔ Reproducible builds
#
# ---
#
# # 🏭 8️⃣ Production Docker Setup (Enterprise Pattern)
#
# ## 🐳 Dockerfile (Multi-stage, Optimized)
#
# ```dockerfile
# # ---------- Builder ----------
# FROM python:3.11-slim AS builder
#
# RUN pip install uv
#
# WORKDIR /app
#
# COPY pyproject.toml uv.lock ./
#
# RUN uv sync --frozen --no-dev
#
# COPY . .
#
# # ---------- Runtime ----------
# FROM python:3.11-slim
#
# WORKDIR /app
#
# COPY --from=builder /app /app
#
# ENV PYTHONUNBUFFERED=1
#
# CMD ["uv", "run", "uvicorn", "src.main:app", "--host", "0.0.0.0", "--port", "8000"]
# ```
#
# ---
#
# # 🐳 9️⃣ docker-compose (Environment Switching)
#
# ```yaml
# version: "3.9"
#
# services:
#   app:
#     build: .
#     env_file:
#       - .env.dev
#     ports:
#       - "8000:8000"
# ```
#
# For staging:
#
# ```yaml
# env_file:
#   - .env.stg
# ```
#
# ---
#
# # 🔄 1️⃣0️⃣ Deployment Flow
#
# ## 🧑‍💻 DEV
#
# ```
# uv add newpackage
# uv sync
# git push
# ```
#
# ---
#
# ## 🧪 QA
#
# CI runs:
#
# ```
# uv sync --frozen
# pytest
# lint
# ```
#
# ---
#
# ## 🚦 STAGING
#
# ```
# docker build -t myapp:stg .
# docker run --env-file .env.stg myapp:stg
# ```
#
# Test with real infra.
#
# ---
#
# ## 🚀 PROD
#
# ```
# docker build -t myapp:prod .
# docker run --env-file .env.prod myapp:prod
# ```
#
# ---
#
# # 🔒 1️⃣1️⃣ Production Hardening Checklist
#
# ✔ Use `--no-dev` in production
# ✔ Use `--frozen` always in CI
# ✔ Use environment variables (no secrets in repo)
# ✔ Multi-stage Docker builds
# ✔ Pin Python version
# ✔ Add healthcheck endpoint
#
# ---
#
# # 📊 1️⃣2️⃣ Advanced: Versioning Strategy
#
# In `pyproject.toml`:
#
# ```
# version = "1.0.0"
# ```
#
# Follow semantic versioning:
#
# ```
# MAJOR.MINOR.PATCH
# ```
#
# Example:
#
# ```
# 1.2.3
# ```
#
# ---
#
# # 🧠 1️⃣3️⃣ Enterprise-Grade Improvements
#
# You can add:
#
# * Alembic migrations
# * Structured logging
# * Centralized config manager
# * Observability (Prometheus)
# * Gunicorn + Uvicorn workers
#
# Example production command:
#
# ```bash
# uv run gunicorn -k uvicorn.workers.UvicornWorker src.main:app
# ```
#
# ---
#
# # 🔥 1️⃣4️⃣ Final Production Architecture Mental Model
#
# ```
# Developer Machine
#     ↓
# uv (lockfile)
#     ↓
# CI (frozen sync)
#     ↓
# Docker Build
#     ↓
# Staging
#     ↓
# Production
# ```
#
# Everything deterministic.
#
# ---
#
# # 🏆 Why This Is Modern Best Practice
#
# | Old Way                | Modern Way           |
# | ---------------------- | -------------------- |
# | pip + requirements.txt | uv + lockfile        |
# | manual venv            | auto venv            |
# | mutable builds         | deterministic builds |
# | inconsistent installs  | frozen sync          |
#
# ---
#
# # 🎯 If You Master This, You’re Production-Ready
#
# You now understand:
#
# * Environment isolation
# * Lockfile control
# * Dev vs Prod separation
# * Docker optimization
# * CI reproducibility
#
# ---
#
# If you'd like next, I can create:
#
# * 🏗 Monorepo microservices template
# * 🔐 Secrets management best practices
# * ☸ Using uv inside Kubernetes
# * ⚡ Performance tuning for production
# * 🧠 How big companies structure Python backends
#
# Tell me your target level: startup / enterprise / FAANG-grade architecture.
