# %% [markdown]
# # 🧠 PYTHON GENERATORS — COMPLETE CHEATSHEET
#
# ---
#
# # 🎯 One-Line Interview Definition (MEMORIZE THIS)
#
# **A generator is a function that produces values one at a time using `yield`, pausing its execution between values instead of returning everything at once.**
#
# Say it confidently → interviewer nods.
#
# ---
#
# # 🔑 The Core Idea
#
# ## Generator = Pause & Resume Function
#
# ### Normal Function
#
# * Runs once
# * Returns everything
# * Dies ❌
#
# ### Generator
#
# * Runs step by step
# * Pauses at `yield`
# * Remembers state ✔
# * Resumes where it stopped ✔
#
# ---
#
# # 🍳 Real-Life Analogy (This Will Stick)
#
# ### Normal function
#
# Cook all dishes → put everything on table at once.
#
# ### Generator
#
# Serve one dish → wait → serve next → wait…
#
# You don’t cook 1000 rotis at once.
# You make one. Serve one.
#
# ---
#
# # 🔄 Normal Function vs Generator
#
# ## Normal Function
#
# ```python
# def numbers():
#     return [1, 2, 3]
# ```
#
# * Stores all values in memory
# * Returns everything at once
#
# ---
#
# ## Generator Function
#
# ```python
# def numbers():
#     yield 1
#     yield 2
#     yield 3
# ```
#
# * Returns one value at a time
# * Saves memory
# * Can pause & resume
#
# ---
#
# # 🔥 What `yield` REALLY Does
#
# `yield`:
#
# * Returns a value
# * Pauses execution
# * Saves:
#
#   * Local variables
#   * Loop state
#   * Execution position
#
# Next call → resumes from exact same place.
#
# That’s the magic ✨
#
# ---
#
# # 🚨 Generator Execution (Big Interview Trap)
#
# ```python
# def my_gen():
#     yield 1
#     yield 2
#
# g = my_gen()
# ```
#
# ❓ Is function executed here?
#
# 👉 **NO**
#
# It only creates a generator object.
#
# Execution starts when you:
#
# * Call `next()`
# * Use a `for` loop
#
# ---
#
# # ▶️ Using Generators
#
# ## 1️⃣ Using `for` loop (Most common)
#
# ```python
# for x in my_gen():
#     print(x)
# ```
#
# ---
#
# ## 2️⃣ Using `next()` (Manual Control)
#
# ```python
# g = my_gen()
# print(next(g))  # 1
# print(next(g))  # 2
# ```
#
# After values finish → `StopIteration`
#
# ---
#
# # 💾 Why Generators Exist (MOST IMPORTANT)
#
# ## ❌ Memory Heavy (List)
#
# ```python
# nums = [i for i in range(1_000_000)]
# ```
#
# Loads everything in memory.
#
# ---
#
# ## ✅ Memory Efficient (Generator)
#
# ```python
# nums = (i for i in range(1_000_000))
# ```
#
# Creates values only when needed.
#
# This answer = interview gold 🥇
#
# ---
#
# # ⚡ Generator Expression (Lambda Cousin)
#
# ## List comprehension
#
# ```python
# [x*x for x in range(5)]
# ```
#
# ## Generator expression
#
# ```python
# (x*x for x in range(5))
# ```
#
# 🧠 Remember:
#
# * `[]` → list (memory heavy)
# * `()` → generator (lazy)
#
# ---
#
# # 📊 Interview Comparison Table
#
# | Feature   | List           | Generator           |
# | --------- | -------------- | ------------------- |
# | Memory    | High           | Low                 |
# | Execution | Immediate      | Lazy                |
# | Reusable  | Yes            | No (one-time)       |
# | Speed     | Fast for small | Best for large data |
#
# Say this word: **lazy evaluation**.
#
# Interviewers love it.
#
# ---
#
# # ♾ Infinite Generators (Powerful Concept)
#
# ```python
# def fibonacci():
#     a, b = 0, 1
#     while True:
#         yield a
#         a, b = b, a + b
# ```
#
# * No memory explosion
# * Infinite sequence
# * Stops when YOU stop
#
# Used in:
#
# * Streaming
# * Logs
# * APIs
# * Pipelines
#
# ---
#
# # 🔁 `yield` vs `return`
#
# ## Using return
#
# ```python
# def square_numbers(nums):
#     result = []
#     for num in nums:
#         result.append(num * num)
#     return result
# ```
#
# ---
#
# ## Using yield
#
# ```python
# def square_numbers(nums):
#     for num in nums:
#         yield num * num
# ```
#
# ---
#
# # ▶️ Using next()
#
# ```python
# my_nums = square_numbers([1, 2, 3, 4, 5])
#
# print(next(my_nums))
# print(next(my_nums))
# ```
#
# ---
#
# # 🚨 Exhaustion
#
# ```python
# print(next(my_nums))  # StopIteration
# ```
#
# Generators are one-time iterators.
#
# ---
#
# # 🔄 Iterating Properly
#
# ```python
# for num in square_numbers([1,2,3,4,5]):
#     print(num)
# ```
#
# ---
#
# # 🔄 Converting Generator to List
#
# ```python
# list(generator)
# ```
#
# ⚠ Warning:
#
# * You lose memory benefit
# * Everything loads into memory
#
# ---
#
# # 🧠 Advanced: `send()` (Interview-Impressive)
#
# Generators can RECEIVE data.
#
# ```python
# def echo():
#     while True:
#         data = yield
#         print(data)
#
# g = echo()
# next(g)          # Prime generator
# g.send("Hello")
# ```
#
# What happens?
#
# * `yield` pauses
# * `"Hello"` is sent into generator
# * Assigned to `data`
# * Printed
#
# ---
#
# ## 🔥 Practical Example
#
# ```python
# def accumulator():
#     total = 0
#     while True:
#         x = yield total
#         if x is not None:
#             total += x
#
# g = accumulator()
#
# print(next(g))       # 0
# print(g.send(5))     # 5
# print(g.send(10))    # 15
# ```
#
# Generator:
#
# * Maintains state
# * Receives values
# * Updates internal memory
#
# Advanced knowledge level ✔
#
# ---
#
# # 🔒 `close()` — Clean Shutdown
#
# ```python
# g.close()
# ```
#
# * Stops generator immediately
# * Executes `finally` block if present
# * Useful for:
#
#   * Files
#   * DB cursors
#   * Resource cleanup
#
# ---
#
# # 🚫 When NOT to Use Generators
#
# Say confidently:
#
# ❌ When data is small
# ❌ When random access needed
# ❌ When multiple passes needed
#
# Generators are one-time streams.
#
# ---
#
# # 🆚 Lambda vs Generator
#
# | Lambda            | Generator            |
# | ----------------- | -------------------- |
# | One-line function | Multi-step execution |
# | No state          | Maintains state      |
# | Immediate result  | Lazy result          |
# | Logic             | Data flow            |
#
# ---
#
# # 🚀 Performance Example (Conceptual)
#
# ## List Version
#
# * Creates 1 million objects
# * Stores all in memory
# * High memory usage
# * Slower startup
#
# ## Generator Version
#
# * Creates nothing initially
# * Produces values on demand
# * Almost no memory spike
# * Instant startup
#
# Generators are powerful only when used lazily.
#
# ---
#
# # 🧠 Final Mental Model
#
# ## Lists
#
# * Cook everything
# * Store everything
# * Serve later
#
# ## Generators
#
# * Cook one
# * Serve immediately
# * Cook next only when needed
#
# ---
#
# # 🎓 10-Second Final Interview Summary
#
# Generators are memory-efficient iterators created using `yield`. They produce values lazily, pause execution between yields, and are ideal for large or infinite data streams where loading everything into memory is inefficient.
#
# ---
#
# # 🔐 Memory Lock (Repeat This)
#
# **Generator = yield + pause + resume + lazy + memory efficient**
#
# ---
#
# Once you understand generators:
#
# 👉 You stop writing memory-hungry code.
# 👉 You start writing professional Python.
