# %% [markdown]
# Perfect 👌
# Here is your **Ultra-Revision Cheatsheet for Data Structures** — designed to:
#
# * 🧠 Stick in long-term memory
# * 🎯 Help in interviews
# * ⚡ Be revised in 10–15 minutes
# * 🏗 Build system-design thinking
#
# ---
#
# # 📘 DATA STRUCTURES – MASTER CHEATSHEET
#
# ---
#
# # 🧠 0. The Golden Rule
#
# > ❌ There is NO best data structure
# > ✅ There is only the right data structure for the constraint
#
# Always ask:
#
# * Does order matter?
# * Do I need fast lookup?
# * Is priority important?
# * Is hierarchy involved?
# * Is memory tight?
# * Is data size fixed?
#
# ---
#
# # 🧾 1. LIST
#
# ### 🧩 Core Idea:
#
# Ordered + Dynamic + Easy to modify
#
# ### 🔁 Behavior:
#
# * Insert: O(n)
# * Delete: O(n)
# * Access by index: O(1)
# * Search: O(n)
#
# ### 🏗 Use When:
#
# * Order matters
# * Items change frequently
# * You append/remove often
#
# ### 🌍 Real Examples:
#
# * Social media feed
# * Shopping cart
# * To-do list
#
# ### ❌ Avoid When:
#
# * Frequent random inserts in middle
# * Need ultra-fast search
#
# ### 🧠 Memory Trick:
#
# > List = Flexible notebook
#
# ---
#
# # 📦 2. ARRAY
#
# ### 🧩 Core Idea:
#
# Fixed size + Contiguous memory + Cache friendly
#
# ### 🔁 Behavior:
#
# * Access: O(1)
# * Insert/Delete: Expensive
# * Very cache efficient
#
# ### 🏗 Use When:
#
# * Size known in advance
# * Heavy numeric computation
# * Performance critical
#
# ### 🌍 Real Examples:
#
# * Image pixels (2D array)
# * Temperature records
# * Matrices
#
# ### ❌ Avoid When:
#
# * Size changes frequently
#
# ### 🧠 Memory Trick:
#
# > Array = Pre-booked seats in a theater
#
# ---
#
# # 📚 3. STACK (LIFO)
#
# ### 🧩 Core Idea:
#
# Last In, First Out
#
# ### 🔁 Operations:
#
# * Push → O(1)
# * Pop → O(1)
#
# ### 🏗 Use When:
#
# * Undo operations
# * Backtracking
# * Function calls
#
# ### 🌍 Real Examples:
#
# * Undo/Redo
# * Browser back button
# * Call stack
#
# ### ❌ Avoid When:
#
# * Need random access
#
# ### 🧠 Memory Trick:
#
# > Stack = Plate pile
#
# ---
#
# # 🚶 4. QUEUE (FIFO)
#
# ### 🧩 Core Idea:
#
# First In, First Out
#
# ### 🔁 Operations:
#
# * Enqueue → O(1)
# * Dequeue → O(1)
#
# ### 🏗 Use When:
#
# * Order must be preserved
# * Processing tasks sequentially
#
# ### 🌍 Real Examples:
#
# * Printer queue
# * Message queue
# * Task scheduler
#
# ### ❌ Avoid When:
#
# * Need priority handling
#
# ### 🧠 Memory Trick:
#
# > Queue = Line at coffee shop
#
# ---
#
# # 🧮 5. HEAP (Priority Queue)
#
# ### 🧩 Core Idea:
#
# Priority > Order
#
# ### 🔁 Operations:
#
# * Insert → O(log n)
# * Remove top → O(log n)
# * Peek → O(1)
#
# ### 🏗 Use When:
#
# * Need highest/lowest quickly
# * Scheduling tasks
# * Dijkstra’s algorithm
#
# ### 🌍 Real Examples:
#
# * OS scheduler
# * Top K problems
# * Real-time systems
#
# ### ❌ Avoid When:
#
# * Need sorted iteration
#
# ### 🧠 Memory Trick:
#
# > Heap = VIP line
#
# ---
#
# # 🌳 6. TREE
#
# ### 🧩 Core Idea:
#
# Hierarchy + Efficient search
#
# ### 🔁 Behavior (Balanced Tree):
#
# * Search → O(log n)
# * Insert → O(log n)
# * Delete → O(log n)
#
# ### 🏗 Use When:
#
# * Hierarchical data
# * Range queries
# * Fast search with ordering
#
# ### 🌍 Real Examples:
#
# * File systems
# * Database indexing
# * Decision trees
#
# ### ❌ Avoid When:
#
# * Simple flat data
#
# ### 🧠 Memory Trick:
#
# > Tree = Family structure
#
# ---
#
# # 🧾 7. HASH TABLE (Dictionary / Map)
#
# ### 🧩 Core Idea:
#
# Key → Value mapping via hash function
#
# ### 🔁 Behavior:
#
# * Insert → O(1) average
# * Lookup → O(1) average
# * Worst case → O(n)
#
# ### 🏗 Use When:
#
# * Fast lookup required
# * Unique keys
# * Caching
#
# ### 🌍 Real Examples:
#
# * Search engines
# * Cache systems
# * Counting frequency
#
# ### ❌ Avoid When:
#
# * Need sorted keys
# * Memory is very limited
#
# ### 🧠 Memory Trick:
#
# > Hash table = Instant address book
#
# ---
#
# # 🔤 8. SUFFIX TREE
#
# ### 🧩 Core Idea:
#
# Efficient substring search
#
# ### 🏗 Use When:
#
# * Pattern matching
# * Large text search
# * DNA analysis
#
# ### 🌍 Real Examples:
#
# * Text editor find
# * Genome search
#
# ### ❌ Avoid When:
#
# * Small strings
# * Memory constrained system
#
# ### 🧠 Memory Trick:
#
# > Suffix tree = Super-powered search
#
# ---
#
# # 🔗 9. GRAPH
#
# ### 🧩 Core Idea:
#
# Nodes + Edges = Relationships
#
# ### 🔁 Types:
#
# * Directed / Undirected
# * Weighted / Unweighted
#
# ### 🏗 Use When:
#
# * Relationships matter
# * Path finding
# * Network modeling
#
# ### 🌍 Real Examples:
#
# * Social networks
# * Google Maps
# * Recommendation engines
#
# ### ❌ Avoid When:
#
# * Data is purely sequential
#
# ### 🧠 Memory Trick:
#
# > Graph = Web of connections
#
# ---
#
# # 📍 10. R-TREE
#
# ### 🧩 Core Idea:
#
# Optimized for spatial data
#
# ### 🏗 Use When:
#
# * Geo queries
# * Nearest neighbor search
# * Bounding boxes
#
# ### 🌍 Real Examples:
#
# * Google Maps
# * Nearby restaurant search
#
# ### ❌ Avoid When:
#
# * Non-spatial data
#
# ### 🧠 Memory Trick:
#
# > R-tree = Map brain
#
# ---
#
# # 🧠 PERFORMANCE THINKING (Very Important)
#
# ## 📌 Cache Friendliness
#
# ### Fast:
#
# * Arrays
# * Contiguous memory
#
# ### Slower:
#
# * Linked lists
# * Pointer-heavy structures
#
# Modern systems:
#
# > Memory access pattern > Time complexity (sometimes)
#
# ---
#
# # ⚔️ INTERVIEW DECISION FRAMEWORK
#
# When interviewer gives a problem:
#
# ### Step 1: Identify pattern
#
# * Need order? → List / Queue
# * Need reverse? → Stack
# * Need fast lookup? → Hash map
# * Need hierarchy? → Tree
# * Need shortest path? → Graph
# * Need top K? → Heap
#
# ### Step 2: Discuss trade-offs
#
# Mention:
#
# * Time complexity
# * Space complexity
# * Cache friendliness
# * Worst case vs average case
#
# ---
#
# # 🧠 SUPER MEMORY TABLE (1-Minute Revision)
#
# | Structure | Best For                | Avoid When           |
# | --------- | ----------------------- | -------------------- |
# | List      | Dynamic ordered data    | Heavy middle inserts |
# | Array     | Fixed size, fast access | Size changes         |
# | Stack     | Undo / recursion        | Random access        |
# | Queue     | Sequential processing   | Priority needed      |
# | Heap      | Top K / priority        | Sorted traversal     |
# | Tree      | Hierarchy / log search  | Flat data            |
# | Hash Map  | Instant lookup          | Need sorting         |
# | Graph     | Relationships           | Linear data          |
# | R-tree    | Spatial search          | Normal data          |
#
# ---
#
# # 🧠 FINAL ENGINEER MINDSET
#
# Good coder:
#
# > Knows syntax
#
# Good developer:
#
# > Knows complexity
#
# Great engineer:
#
# > Knows trade-offs + memory + system constraints
#
# ---
#
# If you want next, I can give you:
#
# * 🎯 1-page printable PDF version
# * 🧠 Interview question mapping (which DS solves which LeetCode pattern)
# * 🏗 System design mapping (which DS used inside real companies)
# * 🎨 ASCII visual diagrams for each structure
# * 🔥 FAANG-level deep dive version
#
# Tell me your goal (interviews / backend / system design / fundamentals mastery) and I’ll tailor it exactly for you.

# %% [markdown]
# Perfect 🔥
# Here’s your **Big-O + Data Structures Long-Term Memory Cheatsheet**
# Designed for:
#
# * 🎯 FAANG interviews
# * 🧠 Concept clarity
# * ⚡ Fast revision
# * 🏗 Engineering thinking
#
# ---
#
# # 🧠 STEP 1: BIG O — The Foundation
#
# ## What is Big O?
#
# > Big O measures how performance changes as input grows.
#
# Not seconds.
# Not milliseconds.
# But **growth rate**.
#
# ---
#
# ## 🚀 1️⃣ O(1) — Constant Time
#
# ### Meaning:
#
# Time stays the same, no matter how big data gets.
#
# ### Think:
#
# Rocket speed 🚀
#
# ### Example:
#
# * Access array index
# * HashMap lookup
#
# 📌 Best possible complexity.
#
# ---
#
# ## 🚗 2️⃣ O(n) — Linear Time
#
# ### Meaning:
#
# If input doubles → time doubles.
#
# ### Think:
#
# Driving across country 🚗
#
# ### Example:
#
# * Linear search
# * Traversing a list
#
# 📌 Predictable but slower than O(1).
#
# ---
#
# ## 🚴 3️⃣ O(n²) — Quadratic Time
#
# ### Meaning:
#
# Work grows explosively.
#
# ### Think:
#
# Biking coast to coast 🚴
#
# ### Example:
#
# * Nested loops
# * Bubble sort
# * All-pairs comparison
#
# 📌 Usually improvable in interviews.
#
# ---
#
# ## 🔊 4️⃣ O(log n) — Logarithmic Time
#
# ### Meaning:
#
# Each step cuts problem in half.
#
# ### Think:
#
# Binary search in dictionary 📖
#
# ### Example:
#
# * Binary search
# * Balanced BST
# * Heap operations
#
# 📌 Scales beautifully.
#
# ---
#
# # 📦 STEP 2: DATA STRUCTURES (With Big O Thinking)
#
# ---
#
# # 🟦 ARRAY — “Lockers in a row”
#
# ### Visual:
#
# [0][1][2][3][4]
#
# ### Properties:
#
# * Contiguous memory
# * Fixed size (conceptually)
# * Indexed access
#
# ### Big O:
#
# | Operation     | Time  |
# | ------------- | ----- |
# | Access        | O(1)  |
# | Insert end    | O(1)* |
# | Insert middle | O(n)  |
# | Delete middle | O(n)  |
#
# *If no resize needed
#
# ### Use When:
#
# * Frequent reads
# * Index-based access
# * Cache efficiency matters
#
# ### Avoid When:
#
# * Heavy insert/delete in middle
#
# 🧠 Anchor: **Array = Lockers**
#
# ---
#
# # 🔗 LINKED LIST — “Train cars”
#
# Node → Node → Node
#
# ### Properties:
#
# * Nodes + pointers
# * Not contiguous
# * Dynamic size
#
# ### Big O:
#
# | Operation             | Time |
# | --------------------- | ---- |
# | Access by index       | O(n) |
# | Insert (with pointer) | O(1) |
# | Delete (with pointer) | O(1) |
#
# ### Use When:
#
# * Many insertions/deletions
# * Size unpredictable
#
# ### Avoid When:
#
# * Need random access
# * Cache efficiency matters
#
# 🧠 Anchor: **Linked List = Train**
#
# ---
#
# # 📚 STACK — LIFO
#
# ### Only top accessible
#
# ### Big O:
#
# | Operation | Time |
# | --------- | ---- |
# | Push      | O(1) |
# | Pop       | O(1) |
# | Search    | O(n) |
#
# ### Used In:
#
# * Function call stack
# * Undo/Redo
# * DFS
#
# 🧠 Anchor: **Stack = Plates**
#
# ---
#
# # 🚶 QUEUE — FIFO
#
# ### Add rear, remove front
#
# ### Big O:
#
# | Operation | Time |
# | --------- | ---- |
# | Enqueue   | O(1) |
# | Dequeue   | O(1) |
#
# ### Used In:
#
# * BFS
# * Scheduling
# * Streaming systems
#
# 🧠 Anchor: **Queue = Store line**
#
# ---
#
# # ⛰️ HEAP — Priority Rules
#
# Binary heap (tree structure)
#
# ### Big O:
#
# | Operation | Time     |
# | --------- | -------- |
# | Peek      | O(1)     |
# | Insert    | O(log n) |
# | Delete    | O(log n) |
#
# ### Used In:
#
# * Top K problems
# * Dijkstra
# * Task scheduling
#
# 🧠 Anchor: **Heap = Pyramid**
#
# ---
#
# # 🧾 HASHMAP — Instant Lookup
#
# Key → Hash → Index
#
# ### Big O (average case):
#
# | Operation | Time |
# | --------- | ---- |
# | Insert    | O(1) |
# | Access    | O(1) |
# | Delete    | O(1) |
#
# Worst case:
# O(n) (collisions)
#
# ### Used In:
#
# * Caching
# * Frequency counting
# * Lookups
#
# 🧠 Anchor: **HashMap = Mailroom**
#
# ---
#
# # 🌳 BINARY SEARCH TREE (BST)
#
# Rule:
# Left < Parent < Right
#
# ### Big O (balanced):
#
# | Operation | Time     |
# | --------- | -------- |
# | Search    | O(log n) |
# | Insert    | O(log n) |
# | Delete    | O(log n) |
#
# Unbalanced:
# O(n)
#
# ### Used In:
#
# * Ordered data
# * Range queries
# * Sorted traversal
#
# 🧠 Anchor: **BST = Family tree**
#
# ---
#
# # 🧿 SET
#
# * Unique elements
# * No duplicates
# * Fast membership test
#
# Usually implemented using HashMap.
#
# ### Big O:
#
# | Operation | Time |
# | --------- | ---- |
# | Insert    | O(1) |
# | Lookup    | O(1) |
# | Delete    | O(1) |
#
# ### Used For:
#
# * Removing duplicates
# * Tracking visited nodes
# * Fast membership check
#
# 🧠 Anchor: **Set = Infinity stones**
#
# ---
#
# # 🧠 INTERVIEW DECISION FLOW
#
# When solving a problem, ask:
#
# ### 1️⃣ Need fast lookup?
#
# → HashMap / Set
#
# ### 2️⃣ Need ordering?
#
# → Array / Tree
#
# ### 3️⃣ Need priority?
#
# → Heap
#
# ### 4️⃣ Need reverse behavior?
#
# → Stack
#
# ### 5️⃣ Need level traversal?
#
# → Queue (BFS)
#
# ### 6️⃣ Need hierarchy?
#
# → Tree
#
# ---
#
# # ⚡ PERFORMANCE REALITY CHECK
#
# Modern systems care about:
#
# * Memory layout
# * Cache friendliness
# * Pointer chasing cost
#
# Fastest in real machines:
#
# * Arrays
#
# Less cache friendly:
#
# * Linked lists
# * Trees (depending on layout)
#
# ---
#
# # 🏆 FINAL ENGINEER MINDSET
#
# Interviewers test:
#
# * Can you identify pattern?
# * Can you choose the right structure?
# * Can you discuss trade-offs?
#
# If you can say:
#
# > “We can use a HashMap here to reduce time from O(n²) to O(n) by trading space for speed.”
#
# You sound like a strong candidate.
#
# ---
#
# # 🔒 SUPER MEMORY ANCHORS
#
# | Structure   | Memory Hook     |
# | ----------- | --------------- |
# | Array       | Lockers         |
# | Linked List | Train           |
# | Stack       | Plates          |
# | Queue       | Store line      |
# | Heap        | Pyramid         |
# | HashMap     | Mailroom        |
# | BST         | Family tree     |
# | Set         | Infinity stones |
#
# ---

# %% [markdown]
# Perfect — let’s break down **how we actually calculate that an algorithm is \(O(\log N)\) instead of \(O(N/2)\)** using **Merge Sort** as an example.
#
# ---
#
# ## Step 1: What we’re measuring
# When we analyze algorithms, we count **the number of basic operations** (comparisons, swaps, recursive calls, etc.) as a function of input size \(N\).
# We don’t care about constants like “divide by 2” because in Big-O notation, constants are ignored.
#
# ---
#
# ## Step 2: Merge Sort process
# Merge Sort works like this:
# 1. **Divide** the array into two halves.
# 2. **Recursively sort** each half.
# 3. **Merge** the two sorted halves.
#
# ---
#
# ## Step 3: Why \(\log N\) appears
# Every time we split the array in half:
# - First split: \(N\) → two arrays of size \(N/2\).
# - Next split: each \(N/2\) → two arrays of size \(N/4\).
# - Next split: each \(N/4\) → two arrays of size \(N/8\).
# - … and so on.
#
# How many times can we keep halving until we reach arrays of size 1?
# That’s exactly \(\log_2 N\).
#
# 👉 Example:
# - \(N = 8\): split → 8 → 4 → 2 → 1 (3 splits = \(\log_2 8 = 3\)).
# - \(N = 16\): split → 16 → 8 → 4 → 2 → 1 (4 splits = \(\log_2 16 = 4\)).
#
# So the **height of the recursion tree** is \(\log N\).
#
# ---
#
# ## Step 4: Why \(N\) also appears
# At each level of recursion:
# - We still need to **merge** all elements back together.
# - Merging takes **linear work** (\(O(N)\)) because every element must be compared and placed.
#
# ---
#
# ## Step 5: Combine them
# - There are \(\log N\) levels (from splitting).
# - Each level requires \(O(N)\) work (from merging).
#
# So total work = \(O(N \cdot \log N)\).
#
# ---
#
# ## Step 6: Why not \(N/2\)?
# - The “divide by 2” is just describing how the array size shrinks each step.
# - But in Big-O, constants like “/2” don’t matter — \(N/2\) is still \(O(N)\).
# - The important part is **how many times we divide** (that’s \(\log N\)) and **how much work per level** (that’s \(N\)).
#
# ---
#
# ✅ **Final takeaway:**
# We confidently say Merge Sort is \(O(N \log N)\) because:
# - Splitting happens \(\log N\) times.
# - Each level of splitting/merging costs \(O(N)\).
# - Multiply them → \(O(N \log N)\).
#
# ---
#
# Would you like me to **draw the recursion tree of Merge Sort** step by step so you can *see* how the \(\log N\) levels and \(N\) work combine?
