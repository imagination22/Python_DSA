# %% [markdown]
# ---
#
# # 🧠 CONCEPTS BEFORE LEARNING DECORATORS
#
# ---
#
# # PART 1 — FIRST-CLASS FUNCTIONS (FOUNDATION)
#
# ---
#
# ## 1️⃣ What Is a First-Class Function?
#
# A language has first-class functions if **functions are treated like normal values**.
#
# That means a function can be:
#
# * Stored in a variable
# * Passed as an argument
# * Returned from another function
#
# 👉 Functions are not “special instructions.”
# They are objects.
#
# ---
#
# ## 2️⃣ What If We DIDN’T Have First-Class Functions?
#
# Imagine:
#
# ```python
# add(2, 3)   # allowed
# x = add     # ❌ not allowed (imaginary restriction)
# ```
#
# If functions were not first-class:
#
# You would NOT have:
#
# * Callbacks
# * Closures
# * Decorators
# * Strategy pattern
# * Functional programming
# * Clean customization of behavior
#
# Code would become rigid and repetitive.
#
# ---
#
# ## 3️⃣ Core Capabilities
#
# ---
#
# ### A) Store a Function in a Variable
#
# ```python
# def greet():
#     return "Hello"
#
# say_hello = greet
# print(say_hello())
# ```
#
# Important:
#
# * `greet` → function object
# * `greet()` → function execution
#
# ---
#
# ### B) Pass Function as Argument (Higher-Order Function)
#
# ```python
# def shout(text):
#     return text.upper()
#
# def whisper(text):
#     return text.lower()
#
# def speak(func):
#     print(func("Hello"))
#
# speak(shout)
# speak(whisper)
# ```
#
# Why this matters:
#
# * Behavior changes without modifying `speak`
# * This enables flexible design
#
# ---
#
# ### C) Return a Function
#
# ```python
# def greeting_maker():
#     def greet():
#         return "Hello!"
#     return greet
#
# hello_func = greeting_maker()
# print(hello_func())
# ```
#
# This is the doorway to **closures**.
#
# ---
#
# ## 4️⃣ Why First-Class Functions Matter
#
# They enable:
#
# * Closures
# * Decorators
# * Middleware
# * Logging wrappers
# * Event systems
# * Dependency injection
#
# Without first-class functions → decorators are impossible.
#
# ---
#
# ## 🔑 Quick Mental Model
#
# First-class functions =
# **Functions behave like variables.**
#
# ---
#
# # PART 2 — CLOSURES
#
# ---
#
# ## 1️⃣ What Is a Closure?
#
# A closure is:
#
# > A function that remembers variables from the scope where it was created.
#
# ---
#
# ## Memory Formula
#
# Closure =
# Function + Remembered Outer Variables
#
# ---
#
# ## 2️⃣ Minimal Example
#
# ```python
# def outer():
#     message = "Hi"
#
#     def inner():
#         print(message)
#
#     return inner
#
# my_func = outer()
# my_func()
# ```
#
# What happened?
#
# * `outer()` finished execution
# * `message` should disappear
# * But `inner()` still remembers it
#
# That remembered value is the closure.
#
# ---
#
# ## 3️⃣ Why Closures Exist
#
# Because:
#
# * Functions are first-class
# * Functions can be returned
# * Inner functions capture outer variables
#
# No first-class functions → no closures.
#
# ---
#
# ## 4️⃣ Custom Behavior with Closures
#
# Instead of writing many fixed functions:
#
# ```python
# def greet(message):
#     def say():
#         print(message)
#     return say
#
# hi = greet("Hi")
# hello = greet("Hello")
#
# hi()
# hello()
# ```
#
# One function → many behaviors.
#
# ---
#
# ## 5️⃣ Practical Example — Function Configuration
#
# ```python
# def power(n):
#     def calculate(x):
#         return x ** n
#     return calculate
#
# square = power(2)
# cube = power(3)
#
# print(square(4))
# print(cube(4))
# ```
#
# Why this works:
#
# * `n` is remembered
# * You configure once
# * Use many times
#
# ---
#
# ## 6️⃣ Real-World Pattern — Logging Wrapper
#
# ```python
# def logger(func):
#     def log(*args):
#         print(f"Calling {func.__name__} with {args}")
#         return func(*args)
#     return log
#
# def add(a, b):
#     return a + b
#
# logged_add = logger(add)
# logged_add(3, 4)
# ```
#
# This pattern becomes decorators later.
#
# ---
#
# ## 7️⃣ What Closures ARE
#
# * Nested functions
# * Remember outer variables
# * Used for customization
# * Lightweight state containers
#
# ---
#
# ## 8️⃣ What Closures Are NOT
#
# * Not global variables
# * Not classes
# * Not magic
# * Not always cleaner
#
# ---
#
# ## 9️⃣ When To Use Closures
#
# Use when:
#
# * You need simple customized behavior
# * You want private data
# * You are writing decorators
# * You need lightweight configuration
#
# ---
#
# ## ⚠️ When NOT To Use Closures
#
# Avoid when:
#
# * State becomes complex
# * You need multiple related methods
# * Logic becomes hard to follow
#
# Rule:
#
# Simple behavior → Closure
# Complex state + many behaviors → Class
#
# ---
#
# ## 🔴 Common Pitfall — Mutable State
#
# ```python
# def counter():
#     count = 0
#
#     def increment():
#         nonlocal count
#         count += 1
#         return count
#
#     return increment
# ```
#
# Works — but can get messy in large systems.
#
# Often better as a class if complexity grows.
#
# ---
#
# # 🎯 10-Second Interview Answers
#
# **First-class functions:**
# Functions are treated like values and can be stored, passed, and returned.
#
# **Closure:**
# A function that remembers variables from its outer scope even after that scope has finished executing.
#
# ---
#
# # 🔒 Final Mental Summary
#
# First-class functions →
# Functions are values.
#
# Closures →
# Functions remember where they were created.
#
# Decorators →
# Functions that wrap other functions using closures.
#
# ---

# %% [markdown]
# Perfect.
# Here is your **clean, structured, confusion-proof Decorators Cheat Sheet** — layered exactly how your brain needs it.
#
# No drama. No fluff. Just clarity.
#
# ---
#
# # 🧠 DECORATORS — COMPLETE CHEAT SHEET
#
# ---
#
# # 1️⃣ What Problem Do Decorators Solve?
#
# You want to:
#
# * Add logging
# * Add authentication
# * Add timing
# * Add validation
# * Add caching
#
# But you **don’t want to modify the original function**.
#
# Without decorators, you'd repeat this everywhere:
#
# ```python
# print("Calling function")
# result = add(2, 3)
# print("Finished")
# ```
#
# Repeated logic = duplication = messy code.
#
# Decorators solve this.
#
# ---
#
# # 2️⃣ Simple Definition (Interview-Ready)
#
# A decorator is:
#
# > A function that takes another function, adds behavior, and returns a new function.
#
# Important:
#
# * The original function is NOT modified.
# * It is replaced.
#
# ---
#
# # 3️⃣ The Core Mental Model
#
# Say this slowly:
#
# A decorator wraps a function and returns a new function.
#
# If this sentence is clear, decorators are clear.
#
# ---
#
# # 4️⃣ Build It From Scratch (No @ Yet)
#
# Forget syntax. Just plain functions.
#
# ---
#
# ## Step A — Functions Are Values
#
# ```python
# def add(a, b):
#     return a + b
#
# x = add
# print(x(2, 3))
# ```
#
# Functions can be stored → first-class functions.
#
# ---
#
# ## Step B — Pass Function Into Function
#
# ```python
# def greet():
#     print("Hello")
#
# def caller(func):
#     func()
#
# caller(greet)
# ```
#
# Functions can be passed → higher-order functions.
#
# ---
#
# ## Step C — Return a Function (Closure Begins)
#
# ```python
# def outer():
#     def inner():
#         print("Hi")
#     return inner
#
# f = outer()
# f()
# ```
#
# Now we have:
#
# Function returning function.
#
# ---
#
# ## Step D — Add Memory (Closure)
#
# ```python
# def outer(message):
#     def inner():
#         print(message)
#     return inner
#
# hi = outer("Hello")
# hi()
# ```
#
# Inner remembers `message`.
#
# That memory = closure.
#
# ---
#
# # 5️⃣ Now Build a Decorator Manually
#
# Goal: Add logging to any function.
#
# ```python
# def logger(func):
#     def wrapper(a, b):
#         print("Calling function")
#         return func(a, b)
#     return wrapper
# ```
#
# Now use it:
#
# ```python
# def add(a, b):
#     return a + b
#
# add = logger(add)
# print(add(2, 3))
# ```
#
# Let’s trace what happened:
#
# | Name    | Points To      |
# | ------- | -------------- |
# | add     | wrapper        |
# | wrapper | remembers func |
# | func    | original add   |
#
# This is the birth of decorators.
#
# ---
#
# # 6️⃣ What @ Syntax Really Means
#
# When Python sees:
#
# ```python
# @logger
# def add(a, b):
#     return a + b
# ```
#
# It does:
#
# ```python
# add = logger(add)
# ```
#
# Nothing more.
#
# No magic.
#
# ---
#
# # 7️⃣ What Decorators Are NOT
#
# They are NOT:
#
# * Inheritance
# * Method overriding
# * Magic
# * Calling function twice
# * Changing execution model
#
# They are simply:
#
# Function replacement.
#
# ---
#
# # 8️⃣ When Should You Use Decorators?
#
# Use when logic is:
#
# * Reusable
# * Independent
# * Cross-cutting
#
# Examples:
#
# ✔ Logging
# ✔ Authentication
# ✔ Timing
# ✔ Caching
# ✔ Validation
#
# Avoid when:
#
# ❌ Business logic
# ❌ Heavy state
# ❌ Complex flows
# ❌ Debug-sensitive code
#
# If it feels confusing → use a class.
#
# ---
#
# # 9️⃣ How To Recognize a Decorator Pattern
#
# Whenever you see:
#
# ```python
# def something(func):
#     def wrapper():
#         func()
#     return wrapper
# ```
#
# That’s a decorator pattern.
#
# With or without `@`.
#
# ---
#
# # 🔟 Decorators With Arguments
#
# Now we go one level deeper.
#
# ---
#
# ## Why Do We Need Arguments?
#
# What if you want:
#
# * A custom log prefix
# * A timeout value
# * A role name
# * A URL path
#
# That configuration cannot live inside wrapper.
#
# It must be outside.
#
# ---
#
# # 🔑 Memory Rule
#
# If a decorator takes arguments, it needs ONE EXTRA FUNCTION LAYER.
#
# ---
#
# # Structure of Decorator With Arguments
#
# Decorator with arguments =
#
# ```
# function(arguments)
#     → decorator(func)
#         → wrapper()
# ```
#
# Three layers.
#
# ---
#
# # Full Example
#
# Goal: Add custom prefix.
#
# ```python
# def prefix_decorator(prefix):
#
#     def decorator(func):
#
#         def wrapper(*args, **kwargs):
#             print(f"{prefix} Before function")
#             result = func(*args, **kwargs)
#             print(f"{prefix} After function")
#             return result
#
#         return wrapper
#
#     return decorator
# ```
#
# Usage:
#
# ```python
# @prefix_decorator("LOG:")
# def display_info(name, age):
#     print(f"Name: {name}, Age: {age}")
# ```
#
# ---
#
# # What Python Actually Does
#
# When Python sees:
#
# ```python
# @prefix_decorator("LOG:")
# def display_info():
#     pass
# ```
#
# It executes:
#
# ```python
# display_info = prefix_decorator("LOG:")(display_info)
# ```
#
# Step-by-step:
#
# 1. `prefix_decorator("LOG:")` runs
# 2. It returns `decorator`
# 3. `decorator(display_info)` runs
# 4. It returns `wrapper`
# 5. `display_info` now points to `wrapper`
#
# That’s it.
#
# ---
#
# # 1️⃣1️⃣ What Decorators With Arguments Are
#
# ✔ Closure
# ✔ Higher-order function
# ✔ Configurable wrapper
# ✔ Common in frameworks
#
# They are NOT:
#
# ❌ New Python feature
# ❌ Magic
# ❌ Required everywhere
#
# ---
#
# # 1️⃣2️⃣ Full Concept Hierarchy
#
# Understand this deeply:
#
# First-Class Functions
# ↓
# Closures
# ↓
# Decorators
#
# Decorators cannot exist without the first two.
#
# ---
#
# # 1️⃣3️⃣ Confidence Test (Answer Without Code)
#
# What happens when Python sees:
#
# ```python
# @decorator
# def func():
#     pass
# ```
#
# Correct answer:
#
# Python replaces `func` with the return value of `decorator(func)`.
#
# If that makes sense → you understand decorators.
#
# ---
#
# # 1️⃣4️⃣ Final Memory Hooks
#
# First-class functions → Functions are values.
# Closures → Functions remember.
# Decorators → Functions wrap other functions.
#
# Decorators with arguments → Function that returns a decorator.
#
# ---
#
# # 🚀 If You Want Next Level
#
# We can now explore:
#
# * `functools.wraps` and metadata preservation
# * Decorating methods vs normal functions
# * Multiple decorators stacking
# * Execution order in stacked decorators
# * Class decorators
# * Real-world framework examples (Flask-style routing)
# * Decorators vs Middleware vs AOP
#
# Tell me which level you want to unlock next.

# %% [markdown]
# ---
#
# # 🧠 MOST IMPORTANT PYTHON DECORATORS (That Save Your Life)
#
# We’ll divide into:
#
# 1️⃣ Built-in (Standard Library)
# 2️⃣ `functools` Power Decorators
# 3️⃣ Class-related Decorators
# 4️⃣ Common Custom Patterns
#
# ---
#
# # 🔥 1️⃣ `@staticmethod`
#
# ### 🎯 Use When:
#
# Method does NOT use `self` or `cls`.
#
# ### Example:
#
# ```python
# class MathUtils:
#
#     @staticmethod
#     def add(a, b):
#         return a + b
# ```
#
# ### Why It’s a Life Saver:
#
# * Keeps function logically grouped inside class
# * No need to create instance
#
# Call it like:
#
# ```python
# MathUtils.add(2, 3)
# ```
#
# ---
#
# # 🔥 2️⃣ `@classmethod`
#
# ### 🎯 Use When:
#
# You need access to the class (`cls`), not instance.
#
# ### Example:
#
# ```python
# class Person:
#
#     def __init__(self, name):
#         self.name = name
#
#     @classmethod
#     def from_string(cls, data):
#         name = data.split("-")[0]
#         return cls(name)
# ```
#
# ### Why It’s Powerful:
#
# * Alternative constructors
# * Factory methods
# * Class-level operations
#
# ---
#
# # 🔥 3️⃣ `@property`
#
# ### 🎯 Use When:
#
# You want method to behave like attribute.
#
# ### Example:
#
# ```python
# class Circle:
#
#     def __init__(self, radius):
#         self.radius = radius
#
#     @property
#     def area(self):
#         return 3.14 * self.radius ** 2
# ```
#
# Use:
#
# ```python
# c = Circle(5)
# print(c.area)  # no ()
# ```
#
# ### Why It’s a Life Saver:
#
# * Encapsulation
# * Validation logic
# * Clean API
#
# ---
#
# # 🔥 4️⃣ `@<property>.setter`
#
# ### 🎯 Use When:
#
# You want controlled attribute updates.
#
# ```python
# class Person:
#
#     def __init__(self, age):
#         self._age = age
#
#     @property
#     def age(self):
#         return self._age
#
#     @age.setter
#     def age(self, value):
#         if value < 0:
#             raise ValueError("Age cannot be negative")
#         self._age = value
# ```
#
# Now validation is automatic.
#
# ---
#
# # 🚀 5️⃣ `@functools.wraps`
#
# ### 🎯 Use When:
#
# You create custom decorators.
#
# Without it:
#
# * Function name changes
# * Docstring lost
# * Debugging painful
#
# ### Example:
#
# ```python
# from functools import wraps
#
# def logger(func):
#
#     @wraps(func)
#     def wrapper(*args, **kwargs):
#         print("Calling function")
#         return func(*args, **kwargs)
#
#     return wrapper
# ```
#
# ### Why It’s CRITICAL:
#
# Preserves:
#
# * `__name__`
# * `__doc__`
# * Metadata
#
# Never write production decorators without this.
#
# ---
#
# # 🚀 6️⃣ `@functools.lru_cache`
#
# ### 🎯 Use When:
#
# Function is expensive and deterministic.
#
# ### Example:
#
# ```python
# from functools import lru_cache
#
# @lru_cache(maxsize=128)
# def fibonacci(n):
#     if n < 2:
#         return n
#     return fibonacci(n-1) + fibonacci(n-2)
# ```
#
# ### Why It’s a Life Saver:
#
# * Automatic memoization
# * Massive speed improvement
# * Zero extra code
#
# Best for:
#
# * Recursion
# * API calls
# * Computation-heavy logic
#
# ---
#
# # 🚀 7️⃣ `@functools.cache` (Python 3.9+)
#
# Same as `lru_cache` but:
#
# * No size limit
#
# ```python
# from functools import cache
#
# @cache
# def compute(x):
#     ...
# ```
#
# ---
#
# # 🚀 8️⃣ `@dataclass` (Very Powerful)
#
# From `dataclasses` module.
#
# ### 🎯 Use When:
#
# You’re writing data containers.
#
# Instead of writing:
#
# * `__init__`
# * `__repr__`
# * `__eq__`
#
# Just do:
#
# ```python
# from dataclasses import dataclass
#
# @dataclass
# class User:
#     name: str
#     age: int
# ```
#
# Python auto-generates:
#
# * Constructor
# * Comparison
# * String representation
#
# Massive boilerplate killer.
#
# ---
#
# # 🚀 9️⃣ `@abstractmethod`
#
# From `abc` module.
#
# ### 🎯 Use When:
#
# You want to force subclasses to implement method.
#
# ```python
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#
#     @abstractmethod
#     def area(self):
#         pass
# ```
#
# Now subclass MUST implement `area()`.
#
# Prevents incomplete implementations.
#
# ---
#
# # 🚀 🔟 `@contextmanager`
#
# From `contextlib`.
#
# ### 🎯 Use When:
#
# You want to create custom `with` blocks.
#
# ```python
# from contextlib import contextmanager
#
# @contextmanager
# def open_file(name):
#     f = open(name)
#     try:
#         yield f
#     finally:
#         f.close()
# ```
#
# Now:
#
# ```python
# with open_file("test.txt") as f:
#     ...
# ```
#
# Super clean resource management.
#
# ---
#
# # 🧠 1️⃣1️⃣ `@singledispatch`
#
# From `functools`.
#
# ### 🎯 Use When:
#
# Function behavior depends on argument type.
#
# ```python
# from functools import singledispatch
#
# @singledispatch
# def process(data):
#     print("Default processing")
#
# @process.register(int)
# def _(data):
#     print("Processing integer")
#
# @process.register(str)
# def _(data):
#     print("Processing string")
# ```
#
# Cleaner alternative to big `if isinstance()` chains.
#
# ---
#
# # 🔥 1️⃣2️⃣ `@pytest.mark.parametrize` (Testing)
#
# If you use pytest:
#
# ```python
# import pytest
#
# @pytest.mark.parametrize("a,b,result", [
#     (2, 3, 5),
#     (4, 5, 9)
# ])
# def test_add(a, b, result):
#     assert a + b == result
# ```
#
# Eliminates repetitive test code.
#
# ---
#
# # 🔥 1️⃣3️⃣ Framework Decorators (Very Common)
#
# ### Flask
#
# ```python
# @app.route("/home")
# ```
#
# ### FastAPI
#
# ```python
# @app.get("/users")
# ```
#
# ### Django
#
# ```python
# @login_required
# ```
#
# These are decorators with arguments.
#
# They:
#
# * Register routes
# * Handle authentication
# * Bind endpoints
#
# ---
#
# # 🏆 Most Important in Real Projects
#
# If you master only these, you're solid:
#
# ✔ `@property`
# ✔ `@classmethod`
# ✔ `@staticmethod`
# ✔ `@wraps`
# ✔ `@lru_cache`
# ✔ `@dataclass`
#
# Everything else is bonus.
#
# ---
#
# # 🧠 Final Memory Map
#
# | Type           | Purpose                  |
# | -------------- | ------------------------ |
# | property       | Clean attribute access   |
# | classmethod    | Alternative constructors |
# | staticmethod   | Utility grouping         |
# | wraps          | Preserve metadata        |
# | lru_cache      | Performance boost        |
# | dataclass      | Remove boilerplate       |
# | abstractmethod | Enforce contracts        |
# | contextmanager | Clean resource handling  |
#
# ---
